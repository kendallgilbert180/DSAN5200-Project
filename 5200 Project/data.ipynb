# %% [markdown]
# ### Data Gathering / Information
#
# <center>
# ![ ](oecd.jpeg){width=50%}</center>
#
# The data that we have chosen to use for this project comes from the OECD. OECD stands for Organization for Economic Co-operation and Development. This organization was founded in 1961, has 38 member countries and was created in attempt to stimulate economic progress and world trade.
#
# The datasets that we will be working with include:
#
# **GDP Data**
#
# - Date Range: 2000 - 2023
# - Unit: GDP, Current PPPs, billions US dollars
# - [Source](https://stats.oecd.org/viewhtml.aspx?datasetcode=NAAG&lang=en#)
#
# **Population Data**
#
# - Date Range: 2000 - 2014
# - [addSource]()
#
# **Net National Income**
#
# - Date Range: 2003 - 2022
# - Unit:
# - [addSource]()
#
# **Infant Mortality**
#
# - Date Range: 1990 - 2019
# - Unit: Deaths per 1000 births
# - [Source](https://stats.oecd.org/viewhtml.aspx?datasetcode=FAMILY&lang=en)
#
# **Fertility**
#
# - Date Range: 1990 - 2023
# - Unit: Children
# - [Source](https://stats.oecd.org/viewhtml.aspx?datasetcode=FAMILY&lang=en)
#
# **Immigrant Inflow**
#
# - Date Range: 2000 - 2022
# - Unit: Inflow of foreign population by nationality
# - [Source](https://stats.oecd.org/viewhtml.aspx?datasetcode=MIG&lang=en)
#
#
# **Paid Maternal Leave**
#
# - Date Range: 1990 - 2022
# - Unit: Weeks
# - [Source](https://stats.oecd.org/viewhtml.aspx?datasetcode=FAMILY&lang=en)
#
#
# **Working Population**
#
# - Date Range: 2011 - 2023
# - Unit: persons in thousands
# - [Source](https://data-explorer.oecd.org/vis?lc=en&fs[0]=Topic%2C1%7CJobs%23JOB%23%7CUnemployment%23JOB_UNEMP%23&pg=0&fc=Topic&bp=true&snb=12&vw=tb&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_ALFS%40DF_SUMTAB&df[ag]=OECD.SDD.TPS&df[vs]=1.0&pd=%2C&dq=.LF.PS._Z._T....A&ly[rw]=REF_AREA&ly[cl]=TIME_PERIOD&to[TIME_PERIOD]=false&lo=13&lom=LASTNPERIODS)
